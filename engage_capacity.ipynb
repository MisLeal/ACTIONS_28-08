# %%
import pandas as pd

# %%
dados_capacity = pd.read_excel('Cópia de CAPACITY TLV_LEAL_CREDOR_ATUALIZADO.xlsx')

# %%
dados_capacity.head()
# Out:
#       DATA CONTRATAÇÃO    DATA INICIO NA OP SUPERVISOR  \
# 0  2024-12-23 00:00:00  2024-12-25 00:00:00          -
# 1  2025-06-12 00:00:00  2025-06-17 00:00:00    Adriana
# 2  2025-01-20 00:00:00  2025-01-23 00:00:00    Cinthya
# 3  2019-04-19 00:00:00  2023-01-01 00:00:00          -
# 4  2024-12-23 00:00:00  2024-12-25 00:00:00    Chayene
#
#                               NOME             CPF USUÁRIO ENGAGE  \
# 0         Adriana Queiroz Da Silva  024.212.311-24    ext_adrsilv
# 1  Aguida Manoela Pereira de Souza  065.990.641-40   ext_aguisouz
# 2    Alessandro Ferreira Rodrigues  711.042.531-27      ext_alesr
# 3             Amanda Macedo Santos  066.719.961-64   ext_amanmace
# 4            Amanda Soares Cardoso  094.538.951-56      ext_amaca
#
#   SENHA ENGAGE USUARIO EXTERNO STATUS                    FUNÇÃO ASSESSORIA  \
# 0    Leal@2025     ext_adrsilv  ATIVO  ASSISTENTE DE SUPERVISÃO       LEAL
# 1    Leal@1806    ext_aguisouz  ATIVO                  OPERADOR       LEAL
# ...

# %%
dados_capacity = dados_capacity[['NOME', 'USUÁRIO ENGAGE']]
dados_capacity
# Out:
#                                      NOME USUÁRIO ENGAGE
# 0                Adriana Queiroz Da Silva    ext_adrsilv
# 1         Aguida Manoela Pereira de Souza   ext_aguisouz
# 2           Alessandro Ferreira Rodrigues      ext_alesr
# 3                    Amanda Macedo Santos   ext_amanmace
# 4                   Amanda Soares Cardoso      ext_amaca
# ..                                    ...            ...
# 175  Valquiria Alves Ferreira de Carvalho   ext_valqucar
# 176                 YASMIN ALVES DE SOUSA      ext_yasms
# 177                Vanessa da Silva Costa      ext_vanec
# 178                  VITOR MORAES MATIAS    ext_vitomati
# 179      Sarah Cristina Costa de Oliveira      ext_sarao
#
# [180 rows x 2 columns]

# %%
dados_capacity.to_csv('capacity.csv', index= False)
